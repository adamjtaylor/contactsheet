# %%
from tifffile import TiffFile
from matplotlib.image import imsave
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from skimage.util import montage
from sklearn.preprocessing import MinMaxScaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/n_/vk78qwsd08g4dsnsghdssg8w0000gn/T/ipykernel_53157/2823300573.py in <module>
#       4 from matplotlib.pyplot import imshow
#       5 from skimage.util import montage
# ----> 6 from sklearn.preprocessing import MinMaxScaler
#       7
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
svs_path = "/Users/ataylor/Downloads/HT 122 P1 S1H3 Vp1 U11.svs"
ome_path = "/Users/ataylor/Documents/projects/htan/htan_imaging_subset_2021-06-02/data/s3/HTA9_1_BA_L_ROI04.ome.tif"

# %%
with TiffFile(svs_path) as tif:
    images = []
    channels = []
    for series in tif.series:
        i = series.levels[-1].asarray()
        images.append(i)

# %%
plt.rcParams['figure.dpi'] = 150 # default for me was 75

# %%
fig, axs = plt.subplots(len(images))
for index, image in enumerate(images):
    axs[index].imshow(image)
    axs[index].axis('off')

# %%
import numpy as np
channel_index = np.argmin(images[0].shape)

# %%
im = images[0]


from skimage.exposure import equalize_adapthist
scaled = np.apply_along_axis(equalize_adapthist, channel_index, im )
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /var/folders/n_/vk78qwsd08g4dsnsghdssg8w0000gn/T/ipykernel_53157/231094349.py in <module>
#       1 im = images[0]
# ----> 2 scaled = np.apply_along_axis(skimage.exposure.equalize_adapthist, channel_index, im)
#
# <__array_function__ internals> in apply_along_axis(*args, **kwargs)
#
# ~/miniforge3/envs/author/lib/python3.9/site-packages/numpy/lib/shape_base.py in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     377             'Cannot apply_along_axis when any iteration dimensions are 0'
#     378         ) from None
# --> 379     res = asanyarray(func1d(inarr_view[ind0], *args, **kwargs))
#     380
#     381     # build a buffer for storing evaluations of func1d.
#
# ~/miniforge3/envs/author/lib/python3.9/site-packages/skimage/color/adapt_rgb.py in image_filter_adapted(image, *args, **kwargs)
#      38                 return apply_to_rgb(image_filter, image, *args, **kwargs)
#      39             else:
# ---> 40                 return image_filter(image, *args, **kwargs)
#      41         return image_filter_adapted
#      42     return decorator
#
# ~/miniforge3/envs/author/lib/python3.9/site-packages/skimage/exposure/_adapthist.py in equalize_adapthist(image, kernel_size, clip_limit, nbins)
#      91     kernel_size = [int(k) for k in kernel_size]
#      92
# ---> 93     image = _clahe(image, kernel_size, clip_limit, nbins)
#      94     image = img_as_float(image)
#      95     return rescale_intensity(image)
#
# ~/miniforge3/envs/author/lib/python3.9/site-packages/skimage/exposure/_adapthist.py in _clahe(image, kernel_size, clip_limit, nbins)
#     129     pad_start_per_dim = [k // 2 for k in kernel_size]
#     130
# --> 131     pad_end_per_dim = [(k - s % k) % k + int(np.ceil(k / 2.))
#     132                        for k, s in zip(kernel_size, image.shape)]
#     133
#
# ~/miniforge3/envs/author/lib/python3.9/site-packages/skimage/exposure/_adapthist.py in <listcomp>(.0)
#     129     pad_start_per_dim = [k // 2 for k in kernel_size]
#     130
# --> 131     pad_end_per_dim = [(k - s % k) % k + int(np.ceil(k / 2.))
#     132                        for k, s in zip(kernel_size, image.shape)]
#     133
#
# ZeroDivisionError: integer division or modulo by zero
